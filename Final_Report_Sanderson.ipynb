# %% [markdown]
# # Forecast of Needed Job Skills for Colorado in 2028
# Government agencies and nonprofits, particularly the US Bureau of Labor Statistics and groups with an interest in education are often attempting to forecast what jobs or careers, and what specific skills will be in demand from employers ten years into the future. This is an example offorecasting or extrapolation. One must make a prediction about what will be the changes in demand for jobs and also what will change in those specific jobs. For one thing the predictions by the US Bureau of Labor Statistics are that jobs for mathematicians and statisticians will beincreasing at a rate much faster than average in the next decade. Secondly, these predictions and the underlying analysis are a great example of the kind of work that mathematicians andstatisticians do.
# This problem is important because if not done it can lead to major shortages across the state in essentail industries. Each industry contributes to our ecconomy and employs thousands if not more of our own. If we lack the ability to employ are people and our GDP takes a hit from the lack of workfoce it can be back for our economy.
#
# 1. A forecast of what industries and careers will growing the fastest and which will not in Colorado in 2028 (what is different from 2018).
# 2. A prediction of what skills Colorado employers will be needing from employees in 2028 (and how that will have changed from 2020).
# 3. An analysis of whether the educational institutions in the state are currently ready to meet that demand, or what transformations are needed in Colorado.
#
# ### Industry Parters - Professionals who provided any guidance
#    - Jean Dougherty - Colorado Department of Labor - Author of The Colorado Talent Pipeline Report
#    - Renise Walker - Colorado Department of Labor
#    - Renee Welch - University of Northern Colorado - Career Services
#    - Michael Culpepper - Office of Labor Market Information - Division of Labor Standards and Statistics
# ### Acknowledgement
#    - PIC Math is a project of the Mathematical Association of America (MAA). Support for this MAA program is provided by the National Sciences Foundation (NSF grant DMS-1722275) and the National Security Agency (NSA).
#
# ### Data - Available open source at these links
# I frequently manipulate this data and use select categories or columns at my choosing to get the best possible results with the models I create. I also use a cross off both data frames. They share a similar column and I was able to merge them based off the rows that had the same OCC_CODE or Occupational Code. I group the rows that have OCC_GROUP 'major' and use them more frequently in the essence of time. They are the 22 over arching industries in Colorado and I think they can be helpful when forecasting this model.
#    - Bureau of Labor Statistics - Workforce Demographic Information for Colorado (05/2018) - https://www.bls.gov/oes/2018/may/oes_co.htm
#        - Contains Current Total Employees, Jobs per 1000, Location ID, Hourly Salary Average, and Annual Salaray Average for Industries and Individual Careers
#    - Projection Central - Long Term Occupational Projections (2016-2026) - https://www.projectionscentral.com/Projections/LongTerm
#        - Contains Individual Careers Current Total Employees, Average Annual Openings, Projected Total Employeees in 2026
#
# ### Results
# * Industries
# After months are research, data engineering, and testing I have come to the conclusion that in Colorado the three industries that I would say that the fastest growing industries according to my data will most likely be Healthcare Practicioners and their technicians, Healthcare Support, Computer and Mathematical, and Education, Training, and Library. I believe that these industries will have a higher than average increase in the size of the work force along with maybe a shortage of employeees to meet the demand by employers. I also believe that these industries that will see a less than average increase or decline in the size of their workforce: Farming, Fishing, Forestry, Construction, and Extraction. I believe that Forestry and Farming accounts for a majority of the loss in that industry considering there isnt much fishing in Colorado. It is also my opinion that construction isnt going to decline as much as Extraction because of the result that I recieved. I have decided to leave out the rest of the idustries because I believe that for the most part they will grow with the population and it is unlikely that there will be a shortaged or an overage of eligable employees.
# * Skills
# I wanted to find a relation between the industries that were going to see the largest increase and decrease and the skills those industries entail. The list of skills is quite long and multiple industries share the same skills. I realized that many of the soft skills are applied to multiple industries and that a majority of them are things that are hard to teach. Soft skills are more learned over time and are effected by ones motivation, personal skills, or just being a good person. I also believe the best way to educate these skills is through social interaction such as grade school and high school which almost all of colorado residents have access too. I believe that the Hard Skills are most quantifiable and are easier to educate quickly and effectively so that they can enter a different workforce quickly. I think currently the state of Colorado should put more focus on Computer and IT skills/certifiations, Healthcare and Nursing Degrees/Certification, and Management/Training programs that teach people to lead/train others.
# - My research has lead me to beleive that Computer and IT skills/certifications would be the easiest to teach due to the multitude of less than one year programs that would allow the person to join the work force with a decent paying job. The programs are also fairly cheap compare to the other options which makes it create for state funded programs and people who might be struggiling financially between jobs. I believe that there is a huge need for people with skills in the healthcare industry and just becuase of the cost and the time of the programs I would say its not a great option for state run programs but I feel that Colorado should still "put more eggs in this basket". As far as managment and traning programs these are fairly easy and short but might be costly for the state to run programs for all the differnt types and demographics that this entails.
#
# Due to impact the current COVID-19 pandemic will have on my projections I decided to consider the effects that this might have and apply it to my models. It ended up having an effect on my final output as expected and placed more significance on essential businesses and businesses that might transition more effectively during these times. I realized that the businesses that fit into these categories would have a higher growth rate or a slower decline during these times and that would cause an increase in the total number of employees in a decade. I tried to apply my same methods I had been working on before the pandemic started and add an extra layer that placed more significance on the industries that my peers and I expect to handle this transition better of than others. Sense I placed more significance on them the results from those inputs should result in slightly higher outputs that the average for the data and thus accounting slightly for the impact of COVID-19.
#
# I also came to the conclusion that this pandemic has absolutely changed the global economy and we will probably experience the effect of it for the rest of our lifes or at least the forseeable future. Taking this into account I would say that all the idustries will shrink slighty or derastically starting right now (04/20) for at least the next year or so which will have a major effect on my predictions and the overall growth rate per industry. It would also be slightly difficult to create a model to predict the effects because of the recent nature of the events and the lack of data. In conclusion, I think COVID-19 will promote an overall decline during the start that will have long last effects which I think will decrease all my predictions by some amount.

# %% [markdown]
# ### Approach
# I assesed the industries in colorado and decided on three different overarching classifications of the inudstries as far as
# a forecast for the number of employees/the need for the job or skill. I said either declining, neutral, or improving were the three that I always kept in the back of my mind. To save time I came up a list of jobs that I thought would remain neutral or grow with the population and cross referenced it with current predictions done by proffesionals and I choose to focus less on that group because I just assumed that the roles would be filled. The big problems I saw was industries in the decline having too many workers and not being able to get other jobs and growing idustries not having enough emoployees to meet demand. Once I was able to identify clusters of industries that would grow and decline I created connections between jobs and skills to see which skills would be in demand and briefly figure out how to educate those skills and what might be the easiest/cheapest.
# ### Going Forward
# If I were to have another 3 months to work on this project I would seriously consider more data to calculate the effects of COVID-19 and try to come to a better conclusion about how that will change my current results. I also would like to consider Colorados economy more and take into account things like GDP and Population.

# %%
import numpy as np                   # Numerical computation library
import pandas as pa                  # Dataframe and Data manipulation Library
import matplotlib.pyplot as plt      # Basic plotting functionality Library
import seaborn as sn                 # Advanced Data visualization Library
import numpy.random as rn
from sklearn.linear_model import LinearRegression, Ridge
import matplotlib.colors as pltco # A package to help with coloring plot
from sklearn.neural_network import MLPRegressor
from sklearn import svm
from sklearn import preprocessing
from sklearn.cluster import KMeans
import matplotlib.cm as cm

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from urllib.request import Request, urlopen
from bs4 import BeautifulSoup
import seaborn as sns
import re

from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import KFold
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.layers import Dense, Activation, Dropout, LSTM
from tensorflow.python.keras.wrappers.scikit_learn import KerasRegressor
from tensorflow.python.keras.activations import relu, sigmoid, linear, exponential, softmax, tanh

from sklearn.svm import LinearSVC
from sklearn.exceptions import FitFailedWarning
import warnings

[x for x in dir(list) if not '__' in x];
import os

from keras.models import load_model
import keras.backend as K

# %% [markdown]
# ### Input data in pandas dataframe

# %%
import Data_Engineering as clean_df

# %%
usable_bls_data = clean_df.clean_bls_data()  # This import a clean dataframe rid of all special characters, np.nan, and all datatypes converted

# %%
usable_projection_central_data = clean_df.clean_projection_central_data() # This import a clean dataframe rid of all special characters, np.nan, and all datatypes converted

# %% [markdown]
# ### Linear Models
# Whenever we first test models on our data it would be best to test to see if there is a linear relationship between some of the data. In this case when I ran the linear models it seems that they are not a very good fit and have really low testing scores

# %%
X = np.atleast_2d(np.array([float(h) for h in usable_bls_data.loc[:, 'TOT_EMP']])).transpose()

y = np.array(usable_bls_data.loc[:, 'H_MEAN'])

# %%
n = X.shape[0]
test = int(0.20*n)            # We will use a test set made up of 20% of the data from our sample
perm = rn.permutation(n)   
X = X[perm]
y = y[perm]
X_test = X[:test]       # Then create the test
y_test = y[:test]
X_train = X[test:]     # and train sets
y_train = y[test:]

# %%
reg = LinearRegression().fit(X_train, y_train)
b, m = reg.intercept_, *reg.coef_
b, m
# Out:
# (27.49368390472149, -1.6766638864103253e-05)

# %%
plt.plot(X_train, y_train, 'b.')
plt.plot(X_test, y_test, 'r+')
xx = np.linspace(0, 0.8, 50)
yy = b + m*xx
plt.plot(xx, yy, 'r-');

# %%
print('Training R2: {}'.format(reg.score(X_train, y_train)))
print('Testing R2: {}'.format(reg.score(X_test, y_test)))
# Out:
# Training R2: 0.0004096872624363979
# Testing R2: -0.0047329777037783405

# %%
X_1 = np.atleast_2d(np.array([float(h) for h in usable_bls_data.loc[:, 'JOBS_1000']])).transpose()

y_1 = np.array(usable_bls_data.loc[:, 'H_MEAN'])

# %%
n = X_1.shape[0]
test = int(0.20*n)            # We will use a test set made up of 20% of the data from our sample
perm = rn.permutation(n)   
X_1 = X_1[perm]
y_1 = y_1[perm]
X_test_1 = X_1[:test]       # Then create the test
y_test_1 = y_1[:test]
X_train_1 = X_1[test:]     # and train sets
y_train_1 = y_1[test:]

# %%
reg1 = Ridge().fit(X_train_1, y_train_1)
b, m = reg.intercept_, *reg.coef_
b, m
# Out:
# (27.49368390472149, -1.6766638864103253e-05)

# %%
plt.plot(X_train_1, y_train_1, 'b.')
plt.plot(X_test_1, y_test_1, 'r+')
xx = np.linspace(0, 0.8, 50)
yy = b + m*xx
plt.plot(xx, yy, 'g-');

# %%
training_1 = reg1.score(X_train, y_train)
testing_1 = reg1.score(X_test, y_test)
print('The training R2: ',abs(training_1))
print('The testing R2:  ',abs(testing_1))
# Out:
# The training R2:  2863.8772023241204
# The testing R2:   10116.349116414787

# %% [markdown]
# ### Nonlieaner Models
# I applied countless different models to my data and found that my data holds a nonlinear relation in the data and it is easier to predict off the data using these types of models. I applied a few different neural network models, some k-nearest neighbors, SVM model, SVC model, and feature correlation. I picked these models because I thought they would return the highest testing scores to predict total employees per industry. I chose to run my models on all my data but picked the best models for the final report and it seems that they are mainly from the bureau of labor statistics data but a combination of both dataframe proved to be useful as well. I liked using annual average opening from the projection central data. I also liked comparing my projections to theirs to see how accurate mine estimates were compare to theres (I did not have any input from them on my project like the people from bls).

# %% [markdown]
# ##### Sequetial Model - Reccurent Neural Network using Keras/Tensor Flow
# This was the best model I found with the lowest loss on the model. I believe that is becuase the SVC model allows for more columns as inputs and doesnt create a convergence warning. In this model we also can tell that my testing data always preformed better and after we ran the model we see that our loss decrease which shows it is learning.

# %%
def loadBLSData(input_data):
    data = input_data
    x = (data[['H_MEAN','JOBS_1000','LOC_Q']])
    x = x.to_numpy()
    x = x.astype(float)
    y = (data[['TOT_EMP']])
    y = y.to_numpy()
    y = y.astype(float)
    y = np.reshape(y, (-1,1))

    return x,y

# %%
x, y = loadBLSData(usable_bls_data)

scaler_x = MinMaxScaler()
scaler_y = MinMaxScaler()
scaler_x.fit(x)
xscale=scaler_x.transform(x)
scaler_y.fit(y)
yscale=scaler_y.transform(y)

X_train_3, X_test_3, y_train_3, y_test_3 = train_test_split(xscale, yscale)

# %%
def plotData(x, y, xlabel, ylabel):
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.scatter([x], [y], marker = 'o')

# %%
def create_model(layers, activation):
    model = Sequential()
    for i, nodes in enumerate(layers):
   
        if(i == 0):
            model.add(Dense(nodes, input_dim = 3, kernel_initializer = 'normal', activation=activation))
            model.add(Dropout(0.25))
        else:
            model.add(Dense(nodes, activation = activation))
      

    model.add(Dense(1, activation = 'linear'))

    model.compile(loss = 'mse', optimizer = 'adam', metrics = ['mse', 'mae'])

    return model

model_checked = KerasRegressor(build_fn = create_model, verbose = 0)

# %%
model = Sequential()
model.add(Dense(64, input_dim = 3, kernel_initializer = 'normal', activation = 'sigmoid'))
model.add(Dropout(0.25))
model.add(Dense(32, activation = 'sigmoid'))
model.add(Dense(16, activation  = 'sigmoid'))
model.add(Dense(1, activation = 'linear'))
model.compile(loss = 'mse', optimizer = 'adam', metrics = ['mse', 'mae'])

# %%
history = model.fit(X_train_3, y_train_3, verbose = 1, validation_split = 0.2, batch_size = 52, epochs = 10)
# Out:
# Train on 1035 samples, validate on 259 samples
# Epoch 1/10
# 1035/1035 [==============================] - 2s 2ms/sample - loss: 0.1477 - mse: 0.1477 - mae: 0.3177 - val_loss: 0.0021 - val_mse: 0.0021 - val_mae: 0.0303
# Epoch 2/10
# 1035/1035 [==============================] - 0s 217us/sample - loss: 0.0119 - mse: 0.0119 - mae: 0.0929 - val_loss: 0.0049 - val_mse: 0.0049 - val_mae: 0.0641
# Epoch 3/10
# 1035/1035 [==============================] - 0s 249us/sample - loss: 0.0045 - mse: 0.0045 - mae: 0.0384 - val_loss: 0.0021 - val_mse: 0.0021 - val_mae: 0.0210
# Epoch 4/10
# 1035/1035 [==============================] - 0s 231us/sample - loss: 0.0041 - mse: 0.0041 - mae: 0.0329 - val_loss: 0.0019 - val_mse: 0.0019 - val_mae: 0.0248
# Epoch 5/10
# 1035/1035 [==============================] - 0s 229us/sample - loss: 0.0039 - mse: 0.0039 - mae: 0.0319 - val_loss: 0.0016 - val_mse: 0.0016 - val_mae: 0.0111
# Epoch 6/10
# ...

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('Data Set')
plt.legend(['training', 'testing'], loc = 'upper left')
plt.show()

# %% [markdown]
# ##### Regression Neural Network - from STAT411 - Dr. Pierce
# For this model I also used a merged dataframe. I took the OCC_CODE and Occupational Code from each dataframe and converted them to floats. If the numbers matched in each dataframe then the new dataframe would contain all the other columns that shared the row with whatever OCC_CODE. This way I am able to use data from both place and call it from one dataframe. It also helped becaue everything is the same size now. We do have some loss on the other hand for the careers that were only on one of the dataframes because they would not be transfer over to this dataframe. With more time I might look at what jobs these are becuase we lose about 250 when we merge the two dataframes

# %%
usable_bls_data['OCC_CODE'].astype(float);
usable_projection_central_data['Occupation Code'].astype(float);

# %%
merged_df = pa.merge(left=usable_bls_data, right=usable_projection_central_data, left_on='OCC_CODE', right_on='Occupation Code')

# %%
X = np.array(merged_df[['Average Annual Openings', 'TOT_EMP']])
y = np.array(merged_df[['Projection']])

# %%
def plot_reg_model(reg, X, y):

    # We shuffle the data using a random permutation

    n = X.shape[0]
    test = int(0.20*n)            # We will use a test set made up of 20% of the data from our sample
    perm = rn.permutation(n)   
    X = X[perm]
    y = y[perm]
    X_test = X[:test]       # Then create the test
    y_test = y[:test]
    X_train = X[test:]     # and train sets
    y_train = y[test:]
    
    reg.fit(X_train, y_train) # Fit the model
     
    nn = 200
    # Plot the decision boundary. For that, we will assign a color to each
    # point in the mesh [x_min, m_max]x[y_min, y_max].
    x_min, x_max = X[:, 0].min()-0.1, X[:, 0].max()+0.1
    y_min, y_max = X[:, 1].min()-0.1, X[:, 1].max()+0.1
    xx, yy = np.meshgrid(np.linspace(x_min, x_max, nn),   # Changed the function to use linspace rather than arrange
        np.linspace(y_min, y_max, nn))                    # This keeps us from having to adjust h.
    Z = reg.predict(np.c_[xx.ravel(), yy.ravel()]) # predict

    # Put the result into a color plot
    Z = Z.reshape(xx.shape)

    plt.figure(figsize=(8, 6))
    plt.contour(xx, yy, Z)
    
    plt.scatter(X_train[:, 0], X_train[:, 1], c=y_train, marker='o')
    plt.scatter(X_test[:, 0], X_test[:, 1], c=y_test, marker='+');
    
    print('Training R2: {}'.format(reg.score(X_train, y_train)))
    print('Testing R2: {}'.format(reg.score(X_test, y_test)))
    
    return reg

# %%
v = [0]*X.shape[1]
for k in range(X.shape[1]):
    M = X[:, k].max()
    m = X[:, k].min()
    v[k] = (X[:, k] - m)/(M - m)
Xn = np.c_[v].transpose()   # Note I could not assign these to X because the type was int not float

# %%
mlp = MLPRegressor(hidden_layer_sizes = (100,100,100,100), activation = 'relu', alpha=0.0001)
plot_reg_model(mlp, Xn, y.ravel());
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# Training R2: 0.9832645806919554
# Testing R2: 0.9851160911575477

# %% [markdown]
# #### Other Things I considered
# - I applied a feature correlation model that I used to help determine what features I would use as input into my models. I noticed what skills were most closely related to the projections that have been made and thought they might be the best inputs

# %%
#Using Pearson Correlation
plt.figure(figsize=(12,10))
cor = merged_df[['JOBS_1000', 'LOC_Q', 'A_MEAN', 'Average Annual Openings', 'Projection', 'H_MEAN']].corr()
sn.heatmap(cor, annot=True, cmap=plt.cm.Reds)
plt.show()

# %% [markdown]
# #### Unsupervised Learning - K-Means Clustering Model
# - When I started this project I used this to compare the clusters on careers that BLS and Projection central call industries to clusters that were made based on the data. I used input from my merged dataframe to create clusters and found that they were slightly different. I didnt use these much in my models but I created a different graph to show the relations between my clusters and skills.

# %%
def cluster_plot(cluster, X):
       
    n_clusters = cluster.get_params()['n_clusters']
    cmap_bold = pltco.ListedColormap([cm.hot(k/n_clusters) for k in range(n_clusters) ])  
    # We need a color map that expands to match the number of clusters

    plt.scatter(X[:, 0], X[:, 1], c=cluster.fit_predict(X), cmap=cmap_bold,marker='.')

# %%
unsupervised_df = merged_df[['JOBS_1000', 'LOC_Q', 'A_MEAN', 'Average Annual Openings', 'Projection', 'H_MEAN']]

# %%
km = KMeans(n_clusters=10).fit(merged_df[['JOBS_1000', 'LOC_Q', 'A_MEAN', 'Average Annual Openings', 'Projection', 'H_MEAN']])

# %%
cluster_map = pa.DataFrame()
cluster_map['Cluster'] = km.labels_
cluster_map['Occupation Title'] = merged_df.OCC_TITLE.values
cluster_map['JOBS PER 1000'] = merged_df.JOBS_1000.values
cluster_map['LOC_Q'] = merged_df.LOC_Q.values
cluster_map["Annual MEAN"] = merged_df.A_MEAN.values
cluster_map["Projection"] = merged_df.Projection.values
cluster_map["Hourly Mean"] = merged_df.H_MEAN.values

# %%
detailed_cluster_example = merged_df[['JOBS_1000', 'LOC_Q', 'A_MEAN', 'Average Annual Openings', 'Projection', 'H_MEAN']].to_numpy()

# %%
cluster_plot(km, detailed_cluster_example)

# %%
def print_clusters ():
    for i in range (10):
        print(cluster_map[cluster_map.Cluster == i])   # I have left out actually printing out all the clusters in efforts to save space bu if you call print_clusters() itll print them all

# %% [markdown]
# #### svm.SVC Model
# - This is another nonlinear model I tested and made it so that it returned a value for on average how far off were my predictions compared to the ones made by Projection Central. I found on average I was about 2500 people away from their prediction which I dont think is super bad when we are talking about the total population of each careers workforce. I decided to use a different model though because of the testing score.

# %%
A = np.array(merged_df[['TOT_EMP','LOC_Q','Average Annual Openings', 'A_MEAN']])
b = np.array(merged_df[['Projection']])

# %%
A_train,A_test,b_train,b_test=train_test_split(A,b,test_size=0.3)

# %%
clf = svm.SVC(C=1.0, kernel='rbf', degree=3, gamma='scale', coef0=0.0, shrinking=True, probability=False, tol=0.001, cache_size=200, class_weight=None, verbose=False, max_iter=-1, decision_function_shape='ovr', random_state=None)      # remove all the stuff inside to see what can go inside this
clf.fit(A_train, b_train.ravel());

# %%
predictions = clf.predict(A_test)

# %%
b_test_array = np.array(b_test)

# %%
total_sum1 = 0

for i in range (len(b_test)):
        distance = abs(b_test_array[[i],:] - predictions[i])
        total_sum1 += distance
    
total_average1 = total_sum1//len(y_test)
print("Average Distance between y_test and SVM predictins:",total_average1)
# Out:
# Average Distance between y_test and SVM predictins: [[2598.]]

# %%
print("svm.SVC testing dats score is: ", clf.score(A_test, b_test.ravel()))
# Out:
# svm.SVC testing dats score is:  0.019002375296912115
